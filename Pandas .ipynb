# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv",header=None)

# %%
df.head()
# Out:
#              0            1            2            3            4  \
# 0     header 0     header 1     header 2     header 3     header 4
# 1  row 1 col 0  row 1 col 1  row 1 col 2  row 1 col 3  row 1 col 4
# 2  row 2 col 0  row 2 col 1  row 2 col 2  row 2 col 3  row 2 col 4
# 3  row 3 col 0  row 3 col 1  row 3 col 2  row 3 col 3  row 3 col 4
# 4  row 4 col 0  row 4 col 1  row 4 col 2  row 4 col 3  row 4 col 4
#
#              5            6            7            8            9
# 0     header 5     header 6     header 7     header 8     header 9
# 1  row 1 col 5  row 1 col 6  row 1 col 7  row 1 col 8  row 1 col 9
# 2  row 2 col 5  row 2 col 6  row 2 col 7  row 2 col 8  row 2 col 9
# 3  row 3 col 5  row 3 col 6  row 3 col 7  row 3 col 8  row 3 col 9
# 4  row 4 col 5  row 4 col 6  row 4 col 7  row 4 col 8  row 4 col 9

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data=pd.read_html("https://www.basketball-reference.com/boxscores/?month=4&day=21&year=2015")

# %%
type(data)
# Out:
# list

# %%
df=pd.read_html("https://www.basketball-reference.com/boxscores/?month=4&day=21&year=2015")

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [           0   1      2
#  0     Boston  91  Final
#  1  Cleveland  99    NaN,
#    Unnamed: 0   1   2   3   4
#  0     Boston  26  24  18  23
#  1  Cleveland  25  26  24  24,
#       0              1   2
#  0  PTS   L. James-CLE  30
#  1  TRB  E. Turner-BOS  12,
#           0    1      2
#  0   Dallas   99  Final
#  1  Houston  111    NaN,
#    Unnamed: 0   1   2   3   4
#  0     Dallas  24  27  29  19
#  1    Houston  23  30  28  30,
#       0                1   2
#  0  PTS    D. Howard-HOU  28
#  1  TRB  D. Nowitzki-DAL  13,
#              0    1      2
#  0  Washington  117  Final
#  1     Toronto  106    NaN,
#     Unnamed: 0   1   2   3   4
#  0  Washington  26  34  37  20
#  1     Toronto  31  18  26  31,
#       0                   1   2
#  0  PTS         B. Beal-WAS  28
#  1  TRB  J. Valančiūnas-TOR  10,
#        Eastern Conference                   W                   L  \
#  0      Atlantic Division   Atlantic Division   Atlantic Division
# ...

# %%
data="https://www.basketball-reference.com/leagues/NBA_2015_totals.html"
df=pd.read_html(data)

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1=df[0]

# %%
len(df)
# Out:
# 1

# %%
#to get top most 5 record by defualt if you pass argument then it will fetch that much record
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
#to get bottom records
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# to store the database in the local system 
df1.to_csv("NBA.CSV",index=False  )

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2AD2-D675
#
#  Directory of C:\Users\rajpu
#
# 04/02/2023  01:59 AM             3,369  task 3 Image to Pencil Sketch with Python.ipynb
# 04/26/2023  09:03 PM    <DIR>          .
# 03/30/2023  11:04 PM    <DIR>          ..
# 04/11/2023  08:56 PM    <DIR>          .astropy
# 04/23/2023  02:09 AM             4,071 .bash_history
# 04/22/2023  08:01 PM    <DIR>          .conda
# 03/19/2023  04:13 PM                25 .condarc
# 03/19/2023  04:12 PM    <DIR>          .continuum
# 04/23/2023  12:59 AM                57 .gitconfig
# 02/09/2023  06:27 PM    <DIR>          .idlerc
# 04/23/2023  11:26 PM    <DIR>          .ipynb_checkpoints
# 02/24/2023  11:58 PM    <DIR>          .ipython
# 03/27/2023  03:38 PM    <DIR>          .jupyter
# 04/01/2023  02:08 PM    <DIR>          .keras
# 04/23/2023  02:09 AM                20 .lesshst
# 03/27/2023  04:28 PM    <DIR>          .matplotlib
# 04/12/2023  05:15 PM    <DIR>          .vscode
# ...

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2AD2-D675
#
#  Directory of C:\Users\rajpu
#
# 04/02/2023  01:59 AM             3,369  task 3 Image to Pencil Sketch with Python.ipynb
# 04/26/2023  09:03 PM    <DIR>          .
# 03/30/2023  11:04 PM    <DIR>          ..
# 04/11/2023  08:56 PM    <DIR>          .astropy
# 04/23/2023  02:09 AM             4,071 .bash_history
# 04/22/2023  08:01 PM    <DIR>          .conda
# 03/19/2023  04:13 PM                25 .condarc
# 03/19/2023  04:12 PM    <DIR>          .continuum
# 04/23/2023  12:59 AM                57 .gitconfig
# 02/09/2023  06:27 PM    <DIR>          .idlerc
# 04/23/2023  11:26 PM    <DIR>          .ipynb_checkpoints
# 02/24/2023  11:58 PM    <DIR>          .ipython
# 03/27/2023  03:38 PM    <DIR>          .jupyter
# 04/01/2023  02:08 PM    <DIR>          .keras
# 04/23/2023  02:09 AM                20 .lesshst
# 03/27/2023  04:28 PM    <DIR>          .matplotlib
# 04/12/2023  05:15 PM    <DIR>          .vscode
# ...

# %%
# to read json files
import json

# %%
d="""{ "name":"swaraj",
 "age":23,
 "phone_no":53732,
 "designation":["techear","hod","principal"]
    
}"""

# %%
type(d)
# Out:
# str

# %%
# to read the json file format
result=json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result["name"]
# Out:
# 'swaraj'

# %%
import json

# %%
pd.DataFrame(result["designation"])
# Out:
#            0
# 0    techear
# 1        hod
# 2  principal

# %%
# to read json file 
df3=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
# to read the json in the raw format 
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %% [raw]
# df4=requests.get(url)

# %%
df3
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
data1=df4.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9548\3033822381.py in <module>
# ----> 1 data1=df4.json()
#
# NameError: name 'df4' is not defined

# %%
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9548\2296849294.py in <module>
# ----> 1 data1
#
# NameError: name 'data1' is not defined

# %%
#imported dataset 
data=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# to access only categorial data from given dataset
column_name=data.dtypes[data.dtypes=="object"].index

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
# to get column name where the categorial dataset is present 
column_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# this is categorial data
data[column_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# this is exact number of data of categorial data 
data[column_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to create separete column in the given dataset 
data['ineuron']='swaraj'
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to access only first 15 data from  particular dataset 
data["Name"][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
# to access in what index the null value is present in the dataset
ind=data[data['Age'].isnull()==True].index

# %%
# to get the length of the null value in the dataset 
len(data[data['Age'].isnull()==True].index
)
# Out:
# 177

# %%
# to get the indexes where the null value is present 
data.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# find the person who has paid a higher fare 
max(data["Fare"])
# Out:
# 512.3292

# %%
# find the person who has paid the highest fare 
data[data["Fare"]==max(data["Fare"])]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
"""1.find out the many male and female passanger was  onboraded
2.how many survived we have
3.how many causality we have 
4. what is name of person who is the eldest one
5.how many passanger do we have in first ,second ,third class
6.how many person we have whose name starts with "s"
7.try to create a new column which is sumation of "sibsp" and "parch"
8.how many person do we have below the age of 25
9.how many persoon died whose age was less than 40
10.from the cabin column separete text and numeric value """
# Out:
# '1.find out the many male and female passanger was  onboraded\n2.how many survived we have\n3.how many causality we have \n4. what is name of person who is the eldest one\n5.how many passanger do we have in first ,second ,third class\n6.how many person we have whose name starts with "s"\n7.try to create a new column which is sumation of "sibsp" and "parch"\n8.how many person do we have below the age of 25\n9.how many persoon died whose age was less than 40\n10.from the cabin column separete text and numeric value '

# %%
#1.find out the many male and female passanger was  onboraded
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#2.how many survived we have
len(data[data["Survived"]==1])
# Out:
# 342

# %%
#3.how many causality we have 
len(data[data["Survived"]==0])
# Out:
# 549

# %%
#4. what is name of person who is the eldest one
data[data["Age"]==data["Age"].max()] ["Name"]#
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
#5.how many passanger do we have in first ,second ,third class
data["Pclass"].value_counts()# either you can used this or 2
data.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
#6.how many person we have whose name starts with "s"
len(data[data["Name"].str.startswith("M")])
# Out:
# 74

# %%
#7.try to create a new column which is sumation of "sibsp" and "parch"
data["new"]=data["SibSp"]+data["Parch"]
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new
# 0      0         A/5 21171   7.2500   NaN        S    1
# 1      0          PC 17599  71.2833   C85        C    1
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0
# 3      0            113803  53.1000  C123        S    1
# ...

# %%
#8.how many person do we have below the age of 25
len(data[data["Age"]<25])
# Out:
# 278

# %%
#9.how many persoon died whose age was less than 40
len(data[data["Survived"]==0 &(data["Age"]<40)])
# Out:
# 549

# %%
#10.from the cabin column separete text and numeric value """
df2=pd.DataFrame(data.Cabin.str.split("[a-zA-Z+][^a-zA-Z+]"))
df2.head()
# Out:
#     Cabin
# 0     NaN
# 1   [, 5]
# 2     NaN
# 3  [, 23]
# 4     NaN

# %%
df=pd.read_csv(r"C:\Users\rajpu\Downloads\bank\bank.csv",sep=";")

# %%
df.head(4)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
# 3   30  management  married   tertiary      no     1476     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df.isnull()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
"""1.how many camapign availbale in this dataset
2.how many user do we have with the housing and personal loan 
3.how many person do we have whose age is above 60
4.in which month we have targeted most of the cutomer 
5.which mode of call is giving ypu more result
6.how many enterpreneure do we have in the this list
7.how many cutomeres do we have with negative balance 
8.prepare a group of data based on eduction level."""
# Out:
# '1.how many camapign availbale in this dataset\n2.how many user do we have with the housing and personal loan \n3.how many person do we have whose age is above 60\n4.in which month we have targeted most of the cutomer \n5.which mode of call is giving ypu more result\n6.how many enterpreneure do we have in the this list\n7.how many cutomeres do we have with negative balance \n8.prepare a group of data based on eduction level.'

# %%
""""read all the resume from the ineuron github and create a datafarme as index value and i am expecting a email id ,linkedin id and github id 
 skill as well 
""""

# %%
#1.how many camapign availbale in this dataset
len(df["campaign"].unique())
# Out:
# 32

# %%
#2.how many user do we have with the housing and personal loan 
len(df[(df["housing"]!="Yes")& (df["loan"]!="yes")])
# Out:
# 3830

# %%
#3.how many person do we have whose age is above 60
len(df[df["age"]>60])
# Out:
# 127

# %%
#4.in which month we have targeted most of the cutomer 
df["month"].value_counts().index[0]
# Out:
# 'may'

# %%
#5.which mode of call is giving ypu more result
 df_groupby=df.groupby(["contact","y"]).count() # here we used group by clause to link the two columns 
df_groupby
max(df_groupby.loc["cellular","yes"][0],
df_groupby.loc["telephone","yes"][0],
df_groupby.loc["unknown","yes"][0])
# Out:
# 416

# %%
df_groupby.loc["cellular","yes"][0]
df_groupby.loc["telephone","yes"][0]
df_groupby.loc["unknown","yes"][0]
# Out:
# 61

# %%
#6.how many enterpreaunar do we have
len(df[df["job"]=="entrepreneur"])
# Out:
# 168

# %%
#7.how many cutomeres do we have with negative balance 
len(df[df["balance"]<0])
# Out:
# 366

# %%
#8.prepare a group of data based on eduction level."""
l=[]
for i in df["education"].unique():
    l.append(df[df["education"]==i])

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
data=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to drop a "na" values from the dataset. 
data.dropna() # 0 axis means rows and 1 means column in pandas
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dropna(axis=1,inplace=True)

# %%
data.fillna(12)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.fillna(value=data["Cabin"].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ancoda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ancoda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ancoda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
